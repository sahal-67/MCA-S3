# %%
import pandas as pd
d1={'Rollno':[1,2,3,4],'Name':["lUffy","zoro","sanji","Robin"]}
print(d1)
b=pd.DataFrame(d1)
print(b)
# Out:
# {'Rollno': [1, 2, 3, 4], 'Name': ['lUffy', 'zoro', 'sanji', 'Robin']}
#    Rollno   Name
# 0       1  lUffy
# 1       2   zoro
# 2       3  sanji
# 3       4  Robin

# %%
import pandas as pd
d1=[1,2,3,4]
b=pd.Series(d1)
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd
d1={'Rollno':[1,2,3,4],'Name':["lUffy","zoro","sanji","Robin"]}
# print(d1)
b=pd.DataFrame(d1)
print(b.loc[1])
# Out:
# Rollno       2
# Name      zoro
# Name: 1, dtype: object

# %%
import pandas as pd

d1 = [1, 2, 3, 4]
b = pd.Series(d1, index=["x", "y", "z", "m"])

print(b)
# Out:
# x    1
# y    2
# z    3
# m    4
# dtype: int64

# %%
import pandas as pd
d1=pd.read_csv('jupiterjsm.csv')
print(d1)
# Out:
#      Name gender  Age
# 0     mjk   male   22
# 1  jaseem   male   21
# 2  midlaj   male   24

# %%
import pandas as pd
d1=pd.read_csv('jupiterjsm.csv')
print(d1.head(2))
# Out:
#      Name gender  Age
# 0     mjk   male   22
# 1  jaseem   male   21

# %%
import pandas as pd
d1=pd.read_csv('jupiterjsm.csv')
print(d1.tail(1))
# Out:
#      Name gender  Age
# 2  midlaj   male   24

# %%
import pandas as pd
d1=pd.read_csv('jupiterjsm.csv')
print(d1.tail(5))
b=d1.dropna()
# Out:
#      Name gender  Age
# 0     mjk   male   22
# 1  jaseem   male   21
# 2  midlaj   male   24
